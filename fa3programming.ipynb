# %%
#fa3prog1
#Write a program that:

#a.      Asks for the student’s name
from unicodedata import name


first_name = None
last_name = None
while first_name is None:
    first_name = input("What is your first name? ").upper()
while last_name is None:
    last_name = input("What is your last name? ").upper()

#b.      Asks for the student’s age
age = None
while age is None:
    try: 
        age = int(input("What is your age? "))
    except ValueError:
        print("Please enter a valid age.")
#c.      Asks for the student’s course
course = None
course_list = ['SS','IS','MATH','CS','ENGLISH','FILIPINO','ADTECH','PE','HEALTH','MUSIC','VALED']
while course is None:
    while course not in course_list:
        print(course_list)
        course = input("What is your course? (choose from the list) ") .upper()
        if course not in course_list:
            print("Please choose a valid course from the list.")
#d.      Displays all the entered information in a formatted output
print(f"Student Name: {(first_name)} {(last_name)}\nStudent Age: {age}\nStudent Course: {course}")
# Out:
# ['SS', 'IS', 'MATH', 'CS', 'ENGLISH', 'FILIPINO', 'ADTECH', 'PE', 'HEALTH', 'MUSIC', 'VALED']
# Student Name: LIANDER DISTOR
# Student Age: 13
# Student Course: CS

# %%
#fa3prog2
first_name = None
last_name = None
while first_name is None:
    first_name = input("What is your first name? ").upper()
while last_name is None:
    last_name = input("What is your last name? ").upper()
    
#Write a program that:

#a.       Accepts a student’s exam score
input_score = None
while input_score is None:
    try:
        input_score = float(input("What is your exam score? "))
    except ValueError:
        print("Please enter a valid number for your exam score.")
#b.       Displays “Passed” if the score is 75 or higher
print(f"Your exam score is: {input_score}")
print("Passing score is 75 or higher.")
if input_score >= 75:
    print("Passed")
#c.       Displays “Failed” if the score is below 75
else:
    print("Failed")
# Out:
# Your exam score is: 98.0
# Passing score is 75 or higher.
# Passed

# %%
#fa3prog3

#Input the student’s name and score, then display the corresponding letter grade following this metrics:
first_name = None
last_name = None
while first_name is None:    
    first_name = input("What is your name? ").upper()
while last_name is None:
    last_name = input("What is your last name? ").upper()
input_score = None
while input_score is None:
    try:
        input_score = float(input("What is your exam score? "))
    except ValueError:
        print("Please enter a valid number for your exam score.")

match input_score:
    #90–100 → A
    case score if 90 <= score <= 100:
        print(f"{first_name} {last_name}, your exam score is: {input_score}\nYour letter grade is: A")
    #80–89 → B
    case score if 80 <= score < 90:
        print(f"{first_name} {last_name}, your exam score is: {input_score}\nYour letter grade is: B")
    #70–79 → C
    case score if 70 <= score < 80:
        print(f"{first_name} {last_name}, your exam score is: {input_score}\nYour letter grade is: C")
    #Below 70 → F
    case score if score < 70:
        print(f"{first_name} {last_name}, your exam score is: {input_score}\nYour letter grade is: F")
# Out:
# LIANDER DISTOR, your exam score is: 98.0
# Your letter grade is: A
